# %% [markdown]
# ## Interactive Python 3 Notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = list(range(0,100))
y = [i**3 for i in x]

# %% [markdown]
# ### Plot x and y

# %%
plt.plot(x, y)
